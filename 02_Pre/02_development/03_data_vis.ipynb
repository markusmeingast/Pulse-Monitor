# %%
import pandas as pd
import matplotlib.pyplot as mp

# %%
data1 = pd.read_csv('../01_raw/20190822-092110.csv',header=None,names=['time','signal'])
data2 = pd.read_csv('../01_raw/20190822-093115.csv',header=None,names=['time','signal'])
data3 = pd.read_csv('../01_raw/20190822-094120.csv',header=None,names=['time','signal'])

# %%
fig = mp.figure(figsize=(15,10))
ax0 = fig.add_subplot(111)
ax1 = fig.add_subplot(711)
ax2 = fig.add_subplot(712)
ax3 = fig.add_subplot(713)
ax4 = fig.add_subplot(714)
ax5 = fig.add_subplot(715)
ax6 = fig.add_subplot(716)
ax7 = fig.add_subplot(717)

ax0.spines['top'].set_color('none')
ax0.spines['bottom'].set_color('none')
ax0.spines['left'].set_color('none')
ax0.spines['right'].set_color('none')

idx = 41036
ax1.plot(data1['signal'].iloc[idx-600:idx+600].rolling(4,center=True).mean())
idx = 42011
ax2.plot(data1['signal'].iloc[idx-600:idx+600].rolling(4,center=True).mean())
idx = 43958
ax3.plot(data1['signal'].iloc[idx-600:idx+600].rolling(4,center=True).mean())
idx = 114429
ax4.plot(data1['signal'].iloc[idx-600:idx+600].rolling(4,center=True).mean())
idx = 118371
ax5.plot(data1['signal'].iloc[idx-600:idx+600].rolling(4,center=True).mean())
idx = 108365
ax6.plot(data2['signal'].iloc[idx-600:idx+600].rolling(4,center=True).mean())
idx = 10264
ax7.plot(data3['signal'].iloc[idx-600:idx+600].rolling(4,center=True).mean())
for ax in [ax0,ax1,ax2,ax3,ax4,ax5,ax6,ax7]:
    ax.set_xticks([])
    ax.set_yticks([])
    
ax0.set_ylabel('Analog reading',fontsize=18)
ax0.set_xlabel('6s interval',fontsize=18)
ax1.set_title(' 2019-08-22 09:24:34',y=0.7,loc='left')
ax2.set_title(' 2019-08-22 09:24:40',y=0.7,loc='left')
ax3.set_title(' 2019-08-22 09:24:50',y=0.7,loc='left')
ax4.set_title(' 2019-08-22 09:30:42',y=0.7,loc='left')
ax5.set_title(' 2019-08-22 09:31:02',y=0.7,loc='left')
ax6.set_title(' 2019-08-22 09:40:15',y=0.7,loc='left')
ax7.set_title(' 2019-08-22 09:42:11',y=0.7,loc='left')
# Out:
# Text(0.0, 0.7, ' 2019-08-22 09:42:11')
